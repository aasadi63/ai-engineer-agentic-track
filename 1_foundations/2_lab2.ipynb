# %% [markdown]
# ## Welcome to the Second Lab - Week 1, Day 3
#
# Today we will work with lots of models! This is a way to get comfortable with APIs.

# %% [markdown]
# <table style="margin: 0; text-align: left; width:100%">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../assets/stop.png" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#ff7800;">Important point - please read</h2>
#             <span style="color:#ff7800;">The way I collaborate with you may be different to other courses you've taken. I prefer not to type code while you watch. Rather, I execute Jupyter Labs, like this, and give you an intuition for what's going on. My suggestion is that you carefully execute this yourself, <b>after</b> watching the lecture. Add print statements to understand what's going on, and then come up with your own variations. See Q37 in the <a href="https://edwarddonner.com/avatar?q=37">FAQ</a> for how to set up a separate project for your work.<br/><br/>If you have time, I'd love it if you submit a PR for changes in the community_contributions folder - instructions in the resources. Also, if you have a Github account, use this to showcase your variations. Not only is this essential practice, but it demonstrates your skills to others, including perhaps future clients or employers...<br/>And if you post about it on LinkedIn and tag me, then I'll weigh in to amplify your achievement. If you see other students posting, please give them your encouragement too.
#             </span>
#         </td>
#     </tr>
# </table>

# %%
# Start with imports - ask the Cursor Agent to explain any package that you don't know

import os
import json
from dotenv import load_dotenv
from openai import OpenAI
from IPython.display import Markdown, display

# %%
# Always remember to do this!
load_dotenv(override=True)
# Out:
# True

# %%
# Print the key prefixes to help with any debugging

openai_api_key = os.getenv('OPENAI_API_KEY')
anthropic_api_key = os.getenv('ANTHROPIC_API_KEY')
google_api_key = os.getenv('GOOGLE_API_KEY')
deepseek_api_key = os.getenv('DEEPSEEK_API_KEY')
groq_api_key = os.getenv('GROQ_API_KEY')
grok_api_key = os.getenv('GROK_API_KEY')
openrouter_api_key = os.getenv('OPENROUTER_API_KEY')

if openai_api_key:
    print(f"OpenAI API Key exists and begins {openai_api_key[:8]}")
else:
    print("OpenAI API Key not set")
    
if anthropic_api_key:
    print(f"Anthropic API Key exists and begins {anthropic_api_key[:7]}")
else:
    print("Anthropic API Key not set (and this is optional)")

if google_api_key:
    print(f"Google API Key exists and begins {google_api_key[:2]}")
else:
    print("Google API Key not set (and this is optional)")

if deepseek_api_key:
    print(f"DeepSeek API Key exists and begins {deepseek_api_key[:3]}")
else:
    print("DeepSeek API Key not set (and this is optional)")

if groq_api_key:
    print(f"Groq API Key exists and begins {groq_api_key[:4]}")
else:
    print("Groq API Key not set (and this is optional)")

if grok_api_key:
    print(f"Grok API Key exists and begins {grok_api_key[:4]}")
else:
    print("Grok API Key not set (and this is optional)")

if openrouter_api_key:
    print(f"OpenRouter API Key exists and begins {openrouter_api_key[:6]}") 
else:
    print("OpenRouter API Key not set (and this is optional)")
# Out:
# OpenAI API Key exists and begins sk-proj-
# Anthropic API Key exists and begins sk-ant-
# Google API Key exists and begins AQ
# DeepSeek API Key exists and begins sk-
# Groq API Key exists and begins gsk_
# Grok API Key exists and begins xai-
# OpenRouter API Key exists and begins sk-or-

# %%
request = """
Please come up with a challenging, nuanced question with a succinct answer,
that I can ask a number of LLMs to evaluate their intelligence.
Not a mathematical puzzle, but more of a thought-provoking question that requires intelligent insight.
Include in your question that the answer must be short.
"""
request += "Answer only with the question, no explanation."
messages = [{"role": "user", "content": request}]

# %%
messages
# Out:
# [{'role': 'user',
#   'content': '\nPlease come up with a challenging, nuanced question with a succinct answer,\nthat I can ask a number of LLMs to evaluate their intelligence.\nNot a mathematical puzzle, but more of a thought-provoking question that requires intelligent insight.\nInclude in your question that the answer must be short.\nAnswer only with the question, no explanation.'}]

# %%
openai = OpenAI()

response = openai.chat.completions.create(model="gpt-5.4-mini", messages=messages)
question = response.choices[0].message.content
display(Markdown(question))
# Out:
# You are advising a city that wants to reduce traffic, air pollution, and commuting time without building new roads or banning cars. What single policy would you recommend, and why is it likely to work better than the obvious alternatives? Answer in no more than 3 sentences.

# %% [markdown]
# ## Calling LLMs from multple providers
#
# We are about to call LLMs from many other providers.
# They all provide API endpoints that are compatible with OpenAI, as explained in Guide 9 in the guides folder.
# So we can simply use these endpoints as if we are using OpenAI.
#
# Please note:
#
# I'm going to use lots of LLMs from different providers, but you don't need to! This is only to show their abilities.

# %%
# OpenAI Compatible URLs

ANTHROPIC_BASE_URL = "https://api.anthropic.com/v1/"
DEEPSEEK_BASE_URL = "https://api.deepseek.com/v1"
GEMINI_BASE_URL = "https://generativelanguage.googleapis.com/v1beta/openai/"
GROQ_BASE_URL = "https://api.groq.com/openai/v1"
GROK_BASE_URL = "https://api.x.ai/v1"
OPENROUTER_BASE_URL = "https://openrouter.ai/api/v1"
OLLAMA_BASE_URL = "http://localhost:11434/v1"

# %%
# OpenAI client libraries with the right base_url and key
# If this surprises you, please see Guide 9 in the Guides folder!

anthropic = OpenAI(api_key=anthropic_api_key, base_url=ANTHROPIC_BASE_URL)
deepseek = OpenAI(api_key=deepseek_api_key, base_url=DEEPSEEK_BASE_URL)
gemini = OpenAI(api_key=google_api_key, base_url=GEMINI_BASE_URL)
groq = OpenAI(api_key=groq_api_key, base_url=GROQ_BASE_URL)
grok = OpenAI(api_key=grok_api_key, base_url=GROK_BASE_URL)
openrouter = OpenAI(api_key=openrouter_api_key, base_url=OPENROUTER_BASE_URL)
ollama = OpenAI(base_url=OLLAMA_BASE_URL, api_key="ollama")

# %%
competitors = []
answers = []
messages = [{"role": "user", "content": question}]

# %%
def record(model_name, answer):
    competitors.append(model_name)
    answers.append(answer)
    display(Markdown(answer))

# %%
# The API we know well
# Reasoning effort can be none, low, medium, high, or xhigh

model_name = "gpt-5.4-nano"

response = openai.chat.completions.create(model=model_name, messages=messages, reasoning_effort="none")
answer = response.choices[0].message.content

record(model_name, answer)
# Out:
# Adopt a citywide congestion pricing (tolling vehicles entering or driving through the most congested areas during peak hours). This directly targets traffic volumes by making trips at the times and places with the biggest delays more costly, which lowers congestion, emissions, and travel time without banning cars or building roads. Compared with obvious alternatives like fuel taxes or parking limits, it is more precisely tied to where/when congestion occurs, so it delivers faster, more predictable reductions in driving.

# %%
model_name = "claude-sonnet-4-6"

response = anthropic.chat.completions.create(model=model_name, messages=messages)
answer = response.choices[0].message.content

record(model_name, answer)
# Out:
# I would recommend **congestion pricing** — charging drivers a variable fee to enter high-traffic zones during peak hours. It works better than alternatives like expanded public transit alone or parking restrictions because it directly attacks the root cause (the artificially low cost of driving in dense areas), generates revenue to fund transit improvements simultaneously, and creates a self-regulating system where prices rise precisely when and where congestion is worst. Evidence from London, Stockholm, and Singapore shows it measurably reduces traffic volume, cuts emissions, and shortens commute times without requiring new infrastructure or outright bans.

# %%
model_name = "gemini-3.1-flash-lite"

response = gemini.chat.completions.create(model=model_name, messages=messages)
answer = response.choices[0].message.content

record(model_name, answer)
# Out:
# I recommend implementing **dynamic congestion pricing**, which adjusts toll rates in real-time based on traffic volume to ensure roads remain at optimal capacity. Unlike infrastructure expansion, which induces further demand, or outright bans, which are politically and economically disruptive, this market-based approach incentivizes off-peak travel and public transit use. It effectively manages demand to reduce gridlock and emissions while generating immediate revenue to fund reliable, time-saving transportation alternatives.

# %%
# model_name = "deepseek-v4-flash"

# response = deepseek.chat.completions.create(model=model_name, messages=messages)
# answer = response.choices[0].message.content

# record(model_name, answer)

# %%
model_name = "openai/gpt-oss-120b"

response = groq.chat.completions.create(model=model_name, messages=messages)
answer = response.choices[0].message.content

display(Markdown(answer))
competitors.append(model_name)
answers.append(answer)
# Out:
# Implement citywide congestion pricing with dynamic, time‑of‑day tolls on the most congested corridors. By internalizing the external costs of driving, it immediately shifts trips to off‑peak hours, transit, car‑pooling, or active modes, cutting vehicle miles, emissions, and average travel times; unlike building more roads (which induces demand) or banning cars (which is politically untenable), pricing is market‑based, scalable, and directly targets the root cause of congestion.

# %%
# model_name = "moonshotai/kimi-k2.6"

# response = openrouter.chat.completions.create(model=model_name, messages=messages)
# answer = response.choices[0].message.content

# record(model_name, answer)

# %% [markdown]
# ## For the next cell, we will use Ollama
#
# Ollama runs a local web service that gives an OpenAI compatible endpoint,
# and runs models locally using high performance C++ code.
#
# If you don't have Ollama, install it here by visiting https://ollama.com then pressing Download and following the instructions.
#
# After it's installed, you should be able to visit here: http://localhost:11434 and see the message "Ollama is running"
#
# You might need to restart Cursor (and maybe reboot). Then open a Terminal (control+\`) and run `ollama serve`
#
# Useful Ollama commands (run these in the terminal, or with an exclamation mark in this notebook):
#
# `ollama pull <model_name>` downloads a model locally
# `ollama ls` lists all the models you've downloaded
# `ollama rm <model_name>` deletes the specified model from your downloads

# %% [markdown]
# <table style="margin: 0; text-align: left; width:100%">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../assets/stop.png" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#ff7800;">Super important - ignore me at your peril!</h2>
#             <span style="color:#ff7800;">Many models on Ollama are FAR too large for your home computer. Be sure to browse the models on the Ollama website. Look to use models that are size 3GB or less unless you know better; llama3.2 is a great first choice. Don't pick models that end in :cloud; that's something different (a cloud inference service, like Groq).
#             </span>
#         </td>
#     </tr>
# </table>

# %%
# !ollama pull llama3.2
# Out:
# ]11;?\pulling manifest ⠋ pulling manifest ⠙ pulling manifest ⠹ pulling manifest ⠸ pulling manifest ⠼ pulling manifest ⠴ pulling manifest ⠦ pulling manifest ⠧ pulling manifest ⠇ pulling manifest ⠏ pulling manifest ⠋ pulling manifest ⠙ pulling manifest
# pulling dde5aa3fc5ff:   0% ▕                  ▏ 1.3 MB/2.0 GB                  pulling manifest
# pulling dde5aa3fc5ff:   0% ▕                  ▏ 6.1 MB/2.0 GB                  pulling manifest
# pulling dde5aa3fc5ff:   1% ▕                  ▏  20 MB/2.0 GB                  pulling manifest
# pulling dde5aa3fc5ff:   2% ▕                  ▏  34 MB/2.0 GB                  pulling manifest
# pulling dde5aa3fc5ff:   2% ▕                  ▏  42 MB/2.0 GB                  pulling manifest
# pulling dde5aa3fc5ff:   3% ▕                  ▏  56 MB/2.0 GB                  pulling manifest
# pulling dde5aa3fc5ff:   4% ▕                  ▏  71 MB/2.0 GB                  pulling manifest
# pulling dde5aa3fc5ff:   4% ▕                  ▏  78 MB/2.0 GB                  pulling manifest
# pulling dde5aa3fc5ff:   5% ▕                  ▏  93 MB/2.0 GB                  pulling manifest
# pulling dde5aa3fc5ff:   5% ▕                  ▏ 107 MB/2.0 GB                  pulling manifest
# pulling dde5aa3fc5ff:   6% ▕█                 ▏ 114 MB/2.0 GB  114 MB/s     16spulling manifest
# pulling dde5aa3fc5ff:   6% ▕█                 ▏ 129 MB/2.0 GB  114 MB/s     16spulling manifest
# pulling dde5aa3fc5ff:   7% ▕█                 ▏ 143 MB/2.0 GB  114 MB/s     16spulling manifest
# pulling dde5aa3fc5ff:   7% ▕█                 ▏ 151 MB/2.0 GB  114 MB/s     16spulling manifest
# pulling dde5aa3fc5ff:   8% ▕█                 ▏ 165 MB/2.0 GB  114 MB/s     16spulling manifest
# pulling dde5aa3fc5ff:   9% ▕█                 ▏ 180 MB/2.0 GB  114 MB/s     16spulling manifest
# pulling dde5aa3fc5ff:   9% ▕█                 ▏ 187 MB/2.0 GB  114 MB/s     15spulling manifest
# pulling dde5aa3fc5ff:  10% ▕█                 ▏ 201 MB/2.0 GB  114 MB/s     15spulling manifest
# pulling dde5aa3fc5ff:  11% ▕█                 ▏ 215 MB/2.0 GB  114 MB/s     15spulling manifest
# pulling dde5aa3fc5ff:  11% ▕█                 ▏ 222 MB/2.0 GB  114 MB/s     15spulling manifest
# pulling dde5aa3fc5ff:  12% ▕██                ▏ 237 MB/2.0 GB  118 MB/s     15spulling manifest
# pulling dde5aa3fc5ff:  12% ▕██                ▏ 252 MB/2.0 GB  118 MB/s     14spulling manifest
# pulling dde5aa3fc5ff:  13% ▕██                ▏ 259 MB/2.0 GB  118 MB/s     14spulling manifest
# pulling dde5aa3fc5ff:  14% ▕██                ▏ 274 MB/2.0 GB  118 MB/s     14spulling manifest
# pulling dde5aa3fc5ff:  14% ▕██                ▏ 289 MB/2.0 GB  118 MB/s     14spulling manifest
# pulling dde5aa3fc5ff:  15% ▕██                ▏ 296 MB/2.0 GB  118 MB/s     14spulling manifest
# pulling dde5aa3fc5ff:  15% ▕██                ▏ 311 MB/2.0 GB  118 MB/s     14spulling manifest
# pulling dde5aa3fc5ff:  16% ▕██                ▏ 325 MB/2.0 GB  118 MB/s     14spulling manifest
# pulling dde5aa3fc5ff:  16% ▕██                ▏ 333 MB/2.0 GB  118 MB/s     14spulling manifest
# pulling dde5aa3fc5ff:  17% ▕███               ▏ 347 MB/2.0 GB  118 MB/s     14spulling manifest
# pulling dde5aa3fc5ff:  18% ▕███               ▏ 361 MB/2.0 GB  120 MB/s     13spulling manifest
# pulling dde5aa3fc5ff:  18% ▕███               ▏ 369 MB/2.0 GB  120 MB/s     13spulling manifest
# pulling dde5aa3fc5ff:  19% ▕███               ▏ 383 MB/2.0 GB  120 MB/s     13spulling manifest
# pulling dde5aa3fc5ff:  19% ▕███               ▏ 391 MB/2.0 GB  120 MB/s     13spulling manifest
# pulling dde5aa3fc5ff:  19% ▕███               ▏ 391 MB/2.0 GB  120 MB/s     13spulling manifest
# pulling dde5aa3fc5ff:  20% ▕███               ▏ 402 MB/2.0 GB  120 MB/s     13spulling manifest
# pulling dde5aa3fc5ff:  21% ▕███               ▏ 417 MB/2.0 GB  120 MB/s     13spulling manifest
# pulling dde5aa3fc5ff:  21% ▕███               ▏ 425 MB/2.0 GB  120 MB/s     13spulling manifest
# pulling dde5aa3fc5ff:  22% ▕███               ▏ 435 MB/2.0 GB  120 MB/s     13spulling manifest
# pulling dde5aa3fc5ff:  22% ▕███               ▏ 445 MB/2.0 GB  120 MB/s     13spulling manifest
# pulling dde5aa3fc5ff:  22% ▕████              ▏ 448 MB/2.0 GB  120 MB/s     13spulling manifest
# pulling dde5aa3fc5ff:  23% ▕████              ▏ 459 MB/2.0 GB  113 MB/s     13spulling manifest
# pulling dde5aa3fc5ff:  23% ▕████              ▏ 469 MB/2.0 GB  113 MB/s     13spulling manifest
# pulling dde5aa3fc5ff:  23% ▕████              ▏ 473 MB/2.0 GB  113 MB/s     13spulling manifest
# pulling dde5aa3fc5ff:  24% ▕████              ▏ 484 MB/2.0 GB  113 MB/s     13spulling manifest
# pulling dde5aa3fc5ff:  24% ▕████              ▏ 492 MB/2.0 GB  113 MB/s     13spulling manifest
# pulling dde5aa3fc5ff:  25% ▕████              ▏ 496 MB/2.0 GB  113 MB/s     13spulling manifest
# pulling dde5aa3fc5ff:  25% ▕████              ▏ 505 MB/2.0 GB  113 MB/s     13spulling manifest
# pulling dde5aa3fc5ff:  26% ▕████              ▏ 516 MB/2.0 GB  113 MB/s     13spulling manifest
# pulling dde5aa3fc5ff:  26% ▕████              ▏ 520 MB/2.0 GB  113 MB/s     13spulling manifest
# pulling dde5aa3fc5ff:  26% ▕████              ▏ 531 MB/2.0 GB  113 MB/s     13spulling manifest
# pulling dde5aa3fc5ff:  27% ▕████              ▏ 540 MB/2.0 GB  107 MB/s     13spulling manifest
# pulling dde5aa3fc5ff:  27% ▕████              ▏ 544 MB/2.0 GB  107 MB/s     13spulling manifest
# pulling dde5aa3fc5ff:  27% ▕████              ▏ 553 MB/2.0 GB  107 MB/s     13spulling manifest
# pulling dde5aa3fc5ff:  28% ▕█████             ▏ 563 MB/2.0 GB  107 MB/s     13spulling manifest
# pulling dde5aa3fc5ff:  28% ▕█████             ▏ 567 MB/2.0 GB  107 MB/s     13spulling manifest
# pulling dde5aa3fc5ff:  29% ▕█████             ▏ 577 MB/2.0 GB  107 MB/s     13spulling manifest
# pulling dde5aa3fc5ff:  29% ▕█████             ▏ 586 MB/2.0 GB  107 MB/s     13spulling manifest
# pulling dde5aa3fc5ff:  29% ▕█████             ▏ 591 MB/2.0 GB  107 MB/s     13spulling manifest
# pulling dde5aa3fc5ff:  30% ▕█████             ▏ 599 MB/2.0 GB  107 MB/s     13spulling manifest
# pulling dde5aa3fc5ff:  30% ▕█████             ▏ 609 MB/2.0 GB  107 MB/s     13spulling manifest
# pulling dde5aa3fc5ff:  30% ▕█████             ▏ 615 MB/2.0 GB  102 MB/s     13spulling manifest
# pulling dde5aa3fc5ff:  31% ▕█████             ▏ 624 MB/2.0 GB  102 MB/s     13spulling manifest
# pulling dde5aa3fc5ff:  31% ▕█████             ▏ 634 MB/2.0 GB  102 MB/s     13spulling manifest
# pulling dde5aa3fc5ff:  32% ▕█████             ▏ 638 MB/2.0 GB  102 MB/s     13spulling manifest
# pulling dde5aa3fc5ff:  32% ▕█████             ▏ 648 MB/2.0 GB  102 MB/s     13spulling manifest
# pulling dde5aa3fc5ff:  33% ▕█████             ▏ 656 MB/2.0 GB  102 MB/s     13spulling manifest
# pulling dde5aa3fc5ff:  33% ▕█████             ▏ 661 MB/2.0 GB  102 MB/s     13spulling manifest
# pulling dde5aa3fc5ff:  33% ▕█████             ▏ 670 MB/2.0 GB  102 MB/s     13spulling manifest
# pulling dde5aa3fc5ff:  34% ▕██████            ▏ 679 MB/2.0 GB  102 MB/s     13spulling manifest
# pulling dde5aa3fc5ff:  34% ▕██████            ▏ 684 MB/2.0 GB  102 MB/s     13spulling manifest
# pulling dde5aa3fc5ff:  34% ▕██████            ▏ 695 MB/2.0 GB   99 MB/s     13spulling manifest
# pulling dde5aa3fc5ff:  35% ▕██████            ▏ 704 MB/2.0 GB   99 MB/s     13spulling manifest
# pulling dde5aa3fc5ff:  35% ▕██████            ▏ 709 MB/2.0 GB   99 MB/s     13spulling manifest
# pulling dde5aa3fc5ff:  36% ▕██████            ▏ 719 MB/2.0 GB   99 MB/s     13spulling manifest
# pulling dde5aa3fc5ff:  36% ▕██████            ▏ 728 MB/2.0 GB   99 MB/s     12spulling manifest
# pulling dde5aa3fc5ff:  36% ▕██████            ▏ 732 MB/2.0 GB   99 MB/s     12spulling manifest
# pulling dde5aa3fc5ff:  37% ▕██████            ▏ 742 MB/2.0 GB   99 MB/s     12spulling manifest
# pulling dde5aa3fc5ff:  37% ▕██████            ▏ 751 MB/2.0 GB   99 MB/s     12spulling manifest
# pulling dde5aa3fc5ff:  37% ▕██████            ▏ 755 MB/2.0 GB   99 MB/s     12spulling manifest
# pulling dde5aa3fc5ff:  38% ▕██████            ▏ 767 MB/2.0 GB   99 MB/s     12spulling manifest
# pulling dde5aa3fc5ff:  38% ▕██████            ▏ 775 MB/2.0 GB   96 MB/s     12spulling manifest
# pulling dde5aa3fc5ff:  39% ▕██████            ▏ 779 MB/2.0 GB   96 MB/s     12spulling manifest
# pulling dde5aa3fc5ff:  39% ▕███████           ▏ 788 MB/2.0 GB   96 MB/s     12spulling manifest
# pulling dde5aa3fc5ff:  40% ▕███████           ▏ 798 MB/2.0 GB   96 MB/s     12spulling manifest
# pulling dde5aa3fc5ff:  40% ▕███████           ▏ 802 MB/2.0 GB   96 MB/s     12spulling manifest
# pulling dde5aa3fc5ff:  40% ▕███████           ▏ 812 MB/2.0 GB   96 MB/s     12spulling manifest
# pulling dde5aa3fc5ff:  41% ▕███████           ▏ 821 MB/2.0 GB   96 MB/s     12spulling manifest
# pulling dde5aa3fc5ff:  41% ▕███████           ▏ 826 MB/2.0 GB   96 MB/s     12spulling manifest
# pulling dde5aa3fc5ff:  41% ▕███████           ▏ 836 MB/2.0 GB   96 MB/s     12spulling manifest
# pulling dde5aa3fc5ff:  42% ▕███████           ▏ 845 MB/2.0 GB   96 MB/s     12spulling manifest
# pulling dde5aa3fc5ff:  42% ▕███████           ▏ 850 MB/2.0 GB   96 MB/s     12spulling manifest
# pulling dde5aa3fc5ff:  43% ▕███████           ▏ 859 MB/2.0 GB   94 MB/s     12spulling manifest
# pulling dde5aa3fc5ff:  43% ▕███████           ▏ 870 MB/2.0 GB   94 MB/s     12spulling manifest
# pulling dde5aa3fc5ff:  43% ▕███████           ▏ 875 MB/2.0 GB   94 MB/s     12spulling manifest
# pulling dde5aa3fc5ff:  44% ▕███████           ▏ 884 MB/2.0 GB   94 MB/s     11spulling manifest
# pulling dde5aa3fc5ff:  44% ▕███████           ▏ 892 MB/2.0 GB   94 MB/s     11spulling manifest
# pulling dde5aa3fc5ff:  44% ▕███████           ▏ 896 MB/2.0 GB   94 MB/s     11spulling manifest
# pulling dde5aa3fc5ff:  45% ▕████████          ▏ 906 MB/2.0 GB   94 MB/s     11spulling manifest
# pulling dde5aa3fc5ff:  45% ▕████████          ▏ 917 MB/2.0 GB   94 MB/s     11spulling manifest
# pulling dde5aa3fc5ff:  46% ▕████████          ▏ 921 MB/2.0 GB   94 MB/s     11spulling manifest
# pulling dde5aa3fc5ff:  46% ▕████████          ▏ 932 MB/2.0 GB   94 MB/s     11spulling manifest
# pulling dde5aa3fc5ff:  47% ▕████████          ▏ 941 MB/2.0 GB   91 MB/s     11spulling manifest
# pulling dde5aa3fc5ff:  47% ▕████████          ▏ 946 MB/2.0 GB   91 MB/s     11spulling manifest
# pulling dde5aa3fc5ff:  47% ▕████████          ▏ 952 MB/2.0 GB   91 MB/s     11spulling manifest
# pulling dde5aa3fc5ff:  48% ▕████████          ▏ 962 MB/2.0 GB   91 MB/s     11spulling manifest
# pulling dde5aa3fc5ff:  48% ▕████████          ▏ 968 MB/2.0 GB   91 MB/s     11spulling manifest
# pulling dde5aa3fc5ff:  48% ▕████████          ▏ 978 MB/2.0 GB   91 MB/s     11spulling manifest
# pulling dde5aa3fc5ff:  49% ▕████████          ▏ 987 MB/2.0 GB   91 MB/s     11spulling manifest
# pulling dde5aa3fc5ff:  49% ▕████████          ▏ 992 MB/2.0 GB   91 MB/s     11spulling manifest
# pulling dde5aa3fc5ff:  50% ▕████████          ▏ 1.0 GB/2.0 GB   91 MB/s     11spulling manifest
# pulling dde5aa3fc5ff:  50% ▕█████████         ▏ 1.0 GB/2.0 GB   91 MB/s     11spulling manifest
# pulling dde5aa3fc5ff:  50% ▕█████████         ▏ 1.0 GB/2.0 GB   86 MB/s     11spulling manifest
# pulling dde5aa3fc5ff:  51% ▕█████████         ▏ 1.0 GB/2.0 GB   86 MB/s     11spulling manifest
# pulling dde5aa3fc5ff:  51% ▕█████████         ▏ 1.0 GB/2.0 GB   86 MB/s     11spulling manifest
# pulling dde5aa3fc5ff:  51% ▕█████████         ▏ 1.0 GB/2.0 GB   86 MB/s     11spulling manifest
# pulling dde5aa3fc5ff:  52% ▕█████████         ▏ 1.0 GB/2.0 GB   86 MB/s     11spulling manifest
# pulling dde5aa3fc5ff:  52% ▕█████████         ▏ 1.1 GB/2.0 GB   86 MB/s     11spulling manifest
# pulling dde5aa3fc5ff:  53% ▕█████████         ▏ 1.1 GB/2.0 GB   86 MB/s     11spulling manifest
# pulling dde5aa3fc5ff:  53% ▕█████████         ▏ 1.1 GB/2.0 GB   86 MB/s     10spulling manifest
# pulling dde5aa3fc5ff:  54% ▕█████████         ▏ 1.1 GB/2.0 GB   86 MB/s     10spulling manifest
# pulling dde5aa3fc5ff:  54% ▕█████████         ▏ 1.1 GB/2.0 GB   86 MB/s     10spulling manifest
# pulling dde5aa3fc5ff:  54% ▕█████████         ▏ 1.1 GB/2.0 GB   81 MB/s     11spulling manifest
# pulling dde5aa3fc5ff:  55% ▕█████████         ▏ 1.1 GB/2.0 GB   81 MB/s     11spulling manifest
# pulling dde5aa3fc5ff:  55% ▕█████████         ▏ 1.1 GB/2.0 GB   81 MB/s     11spulling manifest
# pulling dde5aa3fc5ff:  55% ▕█████████         ▏ 1.1 GB/2.0 GB   81 MB/s     11spulling manifest
# pulling dde5aa3fc5ff:  56% ▕██████████        ▏ 1.1 GB/2.0 GB   81 MB/s     10spulling manifest
# pulling dde5aa3fc5ff:  56% ▕██████████        ▏ 1.1 GB/2.0 GB   81 MB/s     10spulling manifest
# pulling dde5aa3fc5ff:  57% ▕██████████        ▏ 1.1 GB/2.0 GB   81 MB/s     10spulling manifest
# pulling dde5aa3fc5ff:  57% ▕██████████        ▏ 1.2 GB/2.0 GB   81 MB/s     10spulling manifest
# pulling dde5aa3fc5ff:  57% ▕██████████        ▏ 1.2 GB/2.0 GB   81 MB/s     10spulling manifest
# pulling dde5aa3fc5ff:  58% ▕██████████        ▏ 1.2 GB/2.0 GB   81 MB/s     10spulling manifest
# pulling dde5aa3fc5ff:  58% ▕██████████        ▏ 1.2 GB/2.0 GB   79 MB/s     10spulling manifest
# pulling dde5aa3fc5ff:  58% ▕██████████        ▏ 1.2 GB/2.0 GB   79 MB/s     10spulling manifest
# pulling dde5aa3fc5ff:  59% ▕██████████        ▏ 1.2 GB/2.0 GB   79 MB/s     10spulling manifest
# pulling dde5aa3fc5ff:  59% ▕██████████        ▏ 1.2 GB/2.0 GB   79 MB/s     10spulling manifest
# pulling dde5aa3fc5ff:  60% ▕██████████        ▏ 1.2 GB/2.0 GB   79 MB/s     10spulling manifest
# pulling dde5aa3fc5ff:  60% ▕██████████        ▏ 1.2 GB/2.0 GB   79 MB/s     10spulling manifest
# pulling dde5aa3fc5ff:  61% ▕██████████        ▏ 1.2 GB/2.0 GB   79 MB/s      9spulling manifest
# pulling dde5aa3fc5ff:  61% ▕██████████        ▏ 1.2 GB/2.0 GB   79 MB/s      9spulling manifest
# pulling dde5aa3fc5ff:  61% ▕███████████       ▏ 1.2 GB/2.0 GB   79 MB/s      9spulling manifest
# pulling dde5aa3fc5ff:  62% ▕███████████       ▏ 1.2 GB/2.0 GB   79 MB/s      9spulling manifest
# pulling dde5aa3fc5ff:  62% ▕███████████       ▏ 1.3 GB/2.0 GB   79 MB/s      9spulling manifest
# pulling dde5aa3fc5ff:  62% ▕███████████       ▏ 1.3 GB/2.0 GB   79 MB/s      9spulling manifest
# pulling dde5aa3fc5ff:  63% ▕███████████       ▏ 1.3 GB/2.0 GB   79 MB/s      9spulling manifest
# pulling dde5aa3fc5ff:  63% ▕███████████       ▏ 1.3 GB/2.0 GB   79 MB/s      9spulling manifest
# pulling dde5aa3fc5ff:  64% ▕███████████       ▏ 1.3 GB/2.0 GB   79 MB/s      9spulling manifest
# pulling dde5aa3fc5ff:  64% ▕███████████       ▏ 1.3 GB/2.0 GB   79 MB/s      9spulling manifest
# pulling dde5aa3fc5ff:  64% ▕███████████       ▏ 1.3 GB/2.0 GB   79 MB/s      9spulling manifest
# pulling dde5aa3fc5ff:  65% ▕███████████       ▏ 1.3 GB/2.0 GB   79 MB/s      8spulling manifest
# pulling dde5aa3fc5ff:  65% ▕███████████       ▏ 1.3 GB/2.0 GB   79 MB/s      8spulling manifest
# pulling dde5aa3fc5ff:  65% ▕███████████       ▏ 1.3 GB/2.0 GB   79 MB/s      8spulling manifest
# pulling dde5aa3fc5ff:  66% ▕███████████       ▏ 1.3 GB/2.0 GB   79 MB/s      8spulling manifest
# pulling dde5aa3fc5ff:  66% ▕███████████       ▏ 1.3 GB/2.0 GB   80 MB/s      8spulling manifest
# pulling dde5aa3fc5ff:  67% ▕███████████       ▏ 1.3 GB/2.0 GB   80 MB/s      8spulling manifest
# pulling dde5aa3fc5ff:  67% ▕████████████      ▏ 1.4 GB/2.0 GB   80 MB/s      8spulling manifest
# pulling dde5aa3fc5ff:  68% ▕████████████      ▏ 1.4 GB/2.0 GB   80 MB/s      8spulling manifest
# pulling dde5aa3fc5ff:  68% ▕████████████      ▏ 1.4 GB/2.0 GB   80 MB/s      8spulling manifest
# pulling dde5aa3fc5ff:  68% ▕████████████      ▏ 1.4 GB/2.0 GB   80 MB/s      8spulling manifest
# pulling dde5aa3fc5ff:  69% ▕████████████      ▏ 1.4 GB/2.0 GB   80 MB/s      7spulling manifest
# pulling dde5aa3fc5ff:  69% ▕████████████      ▏ 1.4 GB/2.0 GB   80 MB/s      7spulling manifest
# pulling dde5aa3fc5ff:  69% ▕████████████      ▏ 1.4 GB/2.0 GB   80 MB/s      7spulling manifest
# pulling dde5aa3fc5ff:  70% ▕████████████      ▏ 1.4 GB/2.0 GB   80 MB/s      7spulling manifest
# pulling dde5aa3fc5ff:  70% ▕████████████      ▏ 1.4 GB/2.0 GB   79 MB/s      7spulling manifest
# pulling dde5aa3fc5ff:  71% ▕████████████      ▏ 1.4 GB/2.0 GB   79 MB/s      7spulling manifest
# pulling dde5aa3fc5ff:  71% ▕████████████      ▏ 1.4 GB/2.0 GB   79 MB/s      7spulling manifest
# pulling dde5aa3fc5ff:  71% ▕████████████      ▏ 1.4 GB/2.0 GB   79 MB/s      7spulling manifest
# pulling dde5aa3fc5ff:  72% ▕████████████      ▏ 1.4 GB/2.0 GB   79 MB/s      7spulling manifest
# pulling dde5aa3fc5ff:  72% ▕█████████████     ▏ 1.5 GB/2.0 GB   79 MB/s      7spulling manifest
# pulling dde5aa3fc5ff:  72% ▕█████████████     ▏ 1.5 GB/2.0 GB   79 MB/s      6spulling manifest
# pulling dde5aa3fc5ff:  73% ▕█████████████     ▏ 1.5 GB/2.0 GB   79 MB/s      6spulling manifest
# pulling dde5aa3fc5ff:  73% ▕█████████████     ▏ 1.5 GB/2.0 GB   79 MB/s      6spulling manifest
# pulling dde5aa3fc5ff:  74% ▕█████████████     ▏ 1.5 GB/2.0 GB   79 MB/s      6spulling manifest
# pulling dde5aa3fc5ff:  74% ▕█████████████     ▏ 1.5 GB/2.0 GB   80 MB/s      6spulling manifest
# pulling dde5aa3fc5ff:  75% ▕█████████████     ▏ 1.5 GB/2.0 GB   80 MB/s      6spulling manifest
# pulling dde5aa3fc5ff:  75% ▕█████████████     ▏ 1.5 GB/2.0 GB   80 MB/s      6spulling manifest
# pulling dde5aa3fc5ff:  75% ▕█████████████     ▏ 1.5 GB/2.0 GB   80 MB/s      6spulling manifest
# pulling dde5aa3fc5ff:  76% ▕█████████████     ▏ 1.5 GB/2.0 GB   80 MB/s      6spulling manifest
# pulling dde5aa3fc5ff:  76% ▕█████████████     ▏ 1.5 GB/2.0 GB   80 MB/s      6spulling manifest
# pulling dde5aa3fc5ff:  76% ▕█████████████     ▏ 1.5 GB/2.0 GB   80 MB/s      5spulling manifest
# pulling dde5aa3fc5ff:  77% ▕█████████████     ▏ 1.6 GB/2.0 GB   80 MB/s      5spulling manifest
# pulling dde5aa3fc5ff:  77% ▕█████████████     ▏ 1.6 GB/2.0 GB   80 MB/s      5spulling manifest
# pulling dde5aa3fc5ff:  78% ▕█████████████     ▏ 1.6 GB/2.0 GB   80 MB/s      5spulling manifest
# pulling dde5aa3fc5ff:  78% ▕██████████████    ▏ 1.6 GB/2.0 GB   80 MB/s      5spulling manifest
# pulling dde5aa3fc5ff:  78% ▕██████████████    ▏ 1.6 GB/2.0 GB   80 MB/s      5spulling manifest
# pulling dde5aa3fc5ff:  79% ▕██████████████    ▏ 1.6 GB/2.0 GB   80 MB/s      5spulling manifest
# pulling dde5aa3fc5ff:  79% ▕██████████████    ▏ 1.6 GB/2.0 GB   80 MB/s      5spulling manifest
# pulling dde5aa3fc5ff:  79% ▕██████████████    ▏ 1.6 GB/2.0 GB   80 MB/s      5spulling manifest
# pulling dde5aa3fc5ff:  80% ▕██████████████    ▏ 1.6 GB/2.0 GB   80 MB/s      5spulling manifest
# pulling dde5aa3fc5ff:  80% ▕██████████████    ▏ 1.6 GB/2.0 GB   80 MB/s      4spulling manifest
# pulling dde5aa3fc5ff:  81% ▕██████████████    ▏ 1.6 GB/2.0 GB   80 MB/s      4spulling manifest
# pulling dde5aa3fc5ff:  81% ▕██████████████    ▏ 1.6 GB/2.0 GB   80 MB/s      4spulling manifest
# pulling dde5aa3fc5ff:  82% ▕██████████████    ▏ 1.6 GB/2.0 GB   80 MB/s      4spulling manifest
# pulling dde5aa3fc5ff:  82% ▕██████████████    ▏ 1.7 GB/2.0 GB   80 MB/s      4spulling manifest
# pulling dde5aa3fc5ff:  82% ▕██████████████    ▏ 1.7 GB/2.0 GB   79 MB/s      4spulling manifest
# pulling dde5aa3fc5ff:  83% ▕██████████████    ▏ 1.7 GB/2.0 GB   79 MB/s      4spulling manifest
# pulling dde5aa3fc5ff:  83% ▕██████████████    ▏ 1.7 GB/2.0 GB   79 MB/s      4spulling manifest
# pulling dde5aa3fc5ff:  83% ▕███████████████   ▏ 1.7 GB/2.0 GB   79 MB/s      4spulling manifest
# pulling dde5aa3fc5ff:  84% ▕███████████████   ▏ 1.7 GB/2.0 GB   79 MB/s      4spulling manifest
# pulling dde5aa3fc5ff:  84% ▕███████████████   ▏ 1.7 GB/2.0 GB   79 MB/s      4spulling manifest
# pulling dde5aa3fc5ff:  84% ▕███████████████   ▏ 1.7 GB/2.0 GB   79 MB/s      3spulling manifest
# pulling dde5aa3fc5ff:  85% ▕███████████████   ▏ 1.7 GB/2.0 GB   79 MB/s      3spulling manifest
# pulling dde5aa3fc5ff:  85% ▕███████████████   ▏ 1.7 GB/2.0 GB   79 MB/s      3spulling manifest
# pulling dde5aa3fc5ff:  86% ▕███████████████   ▏ 1.7 GB/2.0 GB   79 MB/s      3spulling manifest
# pulling dde5aa3fc5ff:  86% ▕███████████████   ▏ 1.7 GB/2.0 GB   79 MB/s      3spulling manifest
# pulling dde5aa3fc5ff:  86% ▕███████████████   ▏ 1.7 GB/2.0 GB   79 MB/s      3spulling manifest
# pulling dde5aa3fc5ff:  87% ▕███████████████   ▏ 1.8 GB/2.0 GB   79 MB/s      3spulling manifest
# pulling dde5aa3fc5ff:  87% ▕███████████████   ▏ 1.8 GB/2.0 GB   79 MB/s      3spulling manifest
# pulling dde5aa3fc5ff:  88% ▕███████████████   ▏ 1.8 GB/2.0 GB   79 MB/s      3spulling manifest
# pulling dde5aa3fc5ff:  88% ▕███████████████   ▏ 1.8 GB/2.0 GB   79 MB/s      3spulling manifest
# pulling dde5aa3fc5ff:  89% ▕███████████████   ▏ 1.8 GB/2.0 GB   79 MB/s      2spulling manifest
# pulling dde5aa3fc5ff:  89% ▕███████████████   ▏ 1.8 GB/2.0 GB   79 MB/s      2spulling manifest
# pulling dde5aa3fc5ff:  89% ▕████████████████  ▏ 1.8 GB/2.0 GB   79 MB/s      2spulling manifest
# pulling dde5aa3fc5ff:  90% ▕████████████████  ▏ 1.8 GB/2.0 GB   79 MB/s      2spulling manifest
# pulling dde5aa3fc5ff:  90% ▕████████████████  ▏ 1.8 GB/2.0 GB   80 MB/s      2spulling manifest
# pulling dde5aa3fc5ff:  90% ▕████████████████  ▏ 1.8 GB/2.0 GB   80 MB/s      2spulling manifest
# pulling dde5aa3fc5ff:  91% ▕████████████████  ▏ 1.8 GB/2.0 GB   80 MB/s      2spulling manifest
# pulling dde5aa3fc5ff:  91% ▕████████████████  ▏ 1.8 GB/2.0 GB   80 MB/s      2spulling manifest
# pulling dde5aa3fc5ff:  92% ▕████████████████  ▏ 1.8 GB/2.0 GB   80 MB/s      2spulling manifest
# pulling dde5aa3fc5ff:  92% ▕████████████████  ▏ 1.9 GB/2.0 GB   80 MB/s      2spulling manifest
# pulling dde5aa3fc5ff:  92% ▕████████████████  ▏ 1.9 GB/2.0 GB   80 MB/s      1spulling manifest
# pulling dde5aa3fc5ff:  93% ▕████████████████  ▏ 1.9 GB/2.0 GB   80 MB/s      1spulling manifest
# pulling dde5aa3fc5ff:  93% ▕████████████████  ▏ 1.9 GB/2.0 GB   80 MB/s      1spulling manifest
# pulling dde5aa3fc5ff:  93% ▕████████████████  ▏ 1.9 GB/2.0 GB   80 MB/s      1spulling manifest
# pulling dde5aa3fc5ff:  94% ▕████████████████  ▏ 1.9 GB/2.0 GB   80 MB/s      1spulling manifest
# pulling dde5aa3fc5ff:  94% ▕████████████████  ▏ 1.9 GB/2.0 GB   80 MB/s      1spulling manifest
# pulling dde5aa3fc5ff:  95% ▕█████████████████ ▏ 1.9 GB/2.0 GB   80 MB/s      1spulling manifest
# pulling dde5aa3fc5ff:  95% ▕█████████████████ ▏ 1.9 GB/2.0 GB   80 MB/s      1spulling manifest
# pulling dde5aa3fc5ff:  95% ▕█████████████████ ▏ 1.9 GB/2.0 GB   80 MB/s      1spulling manifest
# pulling dde5aa3fc5ff:  96% ▕█████████████████ ▏ 1.9 GB/2.0 GB   80 MB/s      1spulling manifest
# pulling dde5aa3fc5ff:  96% ▕█████████████████ ▏ 1.9 GB/2.0 GB   80 MB/s      0spulling manifest
# pulling dde5aa3fc5ff:  97% ▕█████████████████ ▏ 2.0 GB/2.0 GB   80 MB/s      0spulling manifest
# pulling dde5aa3fc5ff:  97% ▕█████████████████ ▏ 2.0 GB/2.0 GB   80 MB/s      0spulling manifest
# pulling dde5aa3fc5ff:  97% ▕█████████████████ ▏ 2.0 GB/2.0 GB   80 MB/s      0spulling manifest
# pulling dde5aa3fc5ff:  98% ▕█████████████████ ▏ 2.0 GB/2.0 GB   79 MB/s      0spulling manifest
# pulling dde5aa3fc5ff:  98% ▕█████████████████ ▏ 2.0 GB/2.0 GB   79 MB/s      0spulling manifest
# pulling dde5aa3fc5ff:  98% ▕█████████████████ ▏ 2.0 GB/2.0 GB   79 MB/s      0spulling manifest
# pulling dde5aa3fc5ff:  99% ▕█████████████████ ▏ 2.0 GB/2.0 GB   79 MB/s      0spulling manifest
# pulling dde5aa3fc5ff:  99% ▕█████████████████ ▏ 2.0 GB/2.0 GB   79 MB/s      0spulling manifest
# pulling dde5aa3fc5ff:  99% ▕█████████████████ ▏ 2.0 GB/2.0 GB   79 MB/s      0spulling manifest
# pulling dde5aa3fc5ff: 100% ▕█████████████████ ▏ 2.0 GB/2.0 GB   79 MB/s      0spulling manifest
# pulling dde5aa3fc5ff: 100% ▕█████████████████ ▏ 2.0 GB/2.0 GB   79 MB/s      0spulling manifest
# pulling dde5aa3fc5ff: 100% ▕█████████████████ ▏ 2.0 GB/2.0 GB   79 MB/s      0spulling manifest
# pulling dde5aa3fc5ff: 100% ▕█████████████████ ▏ 2.0 GB/2.0 GB   79 MB/s      0spulling manifest
# pulling dde5aa3fc5ff: 100% ▕█████████████████ ▏ 2.0 GB/2.0 GB   79 MB/s      0spulling manifest
# pulling dde5aa3fc5ff: 100% ▕█████████████████ ▏ 2.0 GB/2.0 GB   79 MB/s      0spulling manifest
# pulling dde5aa3fc5ff: 100% ▕█████████████████ ▏ 2.0 GB/2.0 GB   79 MB/s      0spulling manifest
# pulling dde5aa3fc5ff: 100% ▕█████████████████ ▏ 2.0 GB/2.0 GB   79 MB/s      0spulling manifest
# pulling dde5aa3fc5ff: 100% ▕█████████████████ ▏ 2.0 GB/2.0 GB   79 MB/s      0spulling manifest
# pulling dde5aa3fc5ff: 100% ▕█████████████████ ▏ 2.0 GB/2.0 GB   79 MB/s      0spulling manifest
# pulling dde5aa3fc5ff: 100% ▕█████████████████ ▏ 2.0 GB/2.0 GB   79 MB/s      0spulling manifest
# pulling dde5aa3fc5ff: 100% ▕█████████████████ ▏ 2.0 GB/2.0 GB   79 MB/s      0spulling manifest
# pulling dde5aa3fc5ff: 100% ▕█████████████████ ▏ 2.0 GB/2.0 GB   79 MB/s      0spulling manifest
# pulling dde5aa3fc5ff: 100% ▕█████████████████ ▏ 2.0 GB/2.0 GB   79 MB/s      0spulling manifest
# pulling dde5aa3fc5ff: 100% ▕█████████████████ ▏ 2.0 GB/2.0 GB   79 MB/s      0spulling manifest
# pulling dde5aa3fc5ff: 100% ▕█████████████████ ▏ 2.0 GB/2.0 GB   79 MB/s      0spulling manifest
# pulling dde5aa3fc5ff: 100% ▕█████████████████ ▏ 2.0 GB/2.0 GB   79 MB/s      0spulling manifest
# pulling dde5aa3fc5ff: 100% ▕█████████████████ ▏ 2.0 GB/2.0 GB   79 MB/s      0spulling manifest
# pulling dde5aa3fc5ff: 100% ▕█████████████████ ▏ 2.0 GB/2.0 GB   79 MB/s      0spulling manifest
# pulling dde5aa3fc5ff: 100% ▕█████████████████ ▏ 2.0 GB/2.0 GB   79 MB/s      0s
# verifying sha256 digest ⠋ pulling manifest
# pulling dde5aa3fc5ff: 100% ▕█████████████████ ▏ 2.0 GB/2.0 GB   79 MB/s      0s
# verifying sha256 digest ⠙ pulling manifest
# pulling dde5aa3fc5ff: 100% ▕█████████████████ ▏ 2.0 GB/2.0 GB   79 MB/s      0s
# verifying sha256 digest ⠹ pulling manifest
# pulling dde5aa3fc5ff: 100% ▕█████████████████ ▏ 2.0 GB/2.0 GB   79 MB/s      0s
# verifying sha256 digest ⠸ pulling manifest
# pulling dde5aa3fc5ff: 100% ▕█████████████████ ▏ 2.0 GB/2.0 GB   79 MB/s      0s
# verifying sha256 digest ⠼ pulling manifest
# pulling dde5aa3fc5ff: 100% ▕█████████████████ ▏ 2.0 GB/2.0 GB   79 MB/s      0s
# verifying sha256 digest ⠴ pulling manifest
# pulling dde5aa3fc5ff: 100% ▕█████████████████ ▏ 2.0 GB/2.0 GB   79 MB/s      0s
# verifying sha256 digest ⠦ pulling manifest
# pulling dde5aa3fc5ff: 100% ▕█████████████████ ▏ 2.0 GB/2.0 GB   79 MB/s      0s
# verifying sha256 digest ⠧ pulling manifest
# pulling dde5aa3fc5ff: 100% ▕█████████████████ ▏ 2.0 GB/2.0 GB   79 MB/s      0s
# verifying sha256 digest ⠇ pulling manifest
# pulling dde5aa3fc5ff: 100% ▕█████████████████ ▏ 2.0 GB/2.0 GB   79 MB/s      0s
# verifying sha256 digest ⠏ pulling manifest
# pulling dde5aa3fc5ff: 100% ▕█████████████████ ▏ 2.0 GB/2.0 GB   79 MB/s      0s
# verifying sha256 digest
# writing manifest
# success

# %%
import requests
requests.get('http://localhost:11434').content
# Out:
# b'Ollama is running'

# %%
import requests
models = requests.get('http://localhost:11434/v1/models').json()
for model in models.get("data"):
    print(model.get("id"))
# Out:
# llama3.2:latest

# %%
model_name = "llama3.2:latest"

response = ollama.chat.completions.create(model=model_name, messages=messages)
answer = response.choices[0].message.content

record(model_name, answer)
# Out:
# I would recommend a "Time-Driven Pricing" policy, which involves implementing variable tolls that depend on the time of day and traffic congestion. This policy would incentivize drivers to avoid peak hours and reduce the number of vehicles on the road, leading to reduced congestion and emissions. By tying tolls to time, this policy incentivizes behavioral changes that are more effective in reducing traffic than simply banning car use or building new roads.

# %%
model_name = "gpt-oss:latest"

response = ollama.chat.completions.create(model=model_name, messages=messages)
answer = response.choices[0].message.content

display(Markdown(answer))
competitors.append(model_name)
answers.append(answer)
# Out:
# **Implement a dynamic congestion‑pricing system:** raise a toll on heavy‑traffic roads during peak hours. This pricing signals drivers to choose off‑peak times, alternate routes, or public transit, thus directly lowering peak traffic and emissions while generating revenue that can be reinvested in transit and bike infrastructure, shortening commutes overall. Unlike bans or new roads, it preserves the right to drive, activates immediately at a low cost, and has proven success in London, Singapore, and Hong Kong.

# %%
model_name = "gemma4:latest"

response = ollama.chat.completions.create(model=model_name, messages=messages)
answer = response.choices[0].message.content

display(Markdown(answer))
competitors.append(model_name)
answers.append(answer)
# Out:
# I recommend implementing a dynamic, real-time congestion and emission-based pricing system for all private vehicles. This policy adjusts the cost of driving—through variable fees and commuter credits—based on specific factors like time of day, current traffic density, and vehicle pollution levels. It is superior because it manages demand by making the *opportunity cost* of driving expensive during peak times, thus optimizing existing infrastructure without the political backlash of outright bans or the high expense of new construction.

# %%
# So where are we?

print(len(competitors))
print(competitors)
print(answers)
# Out:
# 7
# ['gpt-5.4-nano', 'claude-sonnet-4-6', 'gemini-3.1-flash-lite', 'openai/gpt-oss-120b', 'llama3.2:latest', 'gpt-oss:latest', 'gemma4:latest']
# ['Adopt a citywide congestion pricing (tolling vehicles entering or driving through the most congested areas during peak hours). This directly targets traffic volumes by making trips at the times and places with the biggest delays more costly, which lowers congestion, emissions, and travel time without banning cars or building roads. Compared with obvious alternatives like fuel taxes or parking limits, it is more precisely tied to where/when congestion occurs, so it delivers faster, more predictable reductions in driving.', 'I would recommend **congestion pricing** — charging drivers a variable fee to enter high-traffic zones during peak hours. It works better than alternatives like expanded public transit alone or parking restrictions because it directly attacks the root cause (the artificially low cost of driving in dense areas), generates revenue to fund transit improvements simultaneously, and creates a self-regulating system where prices rise precisely when and where congestion is worst. Evidence from London, Stockholm, and Singapore shows it measurably reduces traffic volume, cuts emissions, and shortens commute times without requiring new infrastructure or outright bans.', 'I recommend implementing **dynamic congestion pricing**, which adjusts toll rates in real-time based on traffic volume to ensure roads remain at optimal capacity. Unlike infrastructure expansion, which induces further demand, or outright bans, which are politically and economically disruptive, this market-based approach incentivizes off-peak travel and public transit use. It effectively manages demand to reduce gridlock and emissions while generating immediate revenue to fund reliable, time-saving transportation alternatives.', 'Implement citywide congestion pricing with dynamic, time‑of‑day tolls on the most congested corridors. By internalizing the external costs of driving, it immediately shifts trips to off‑peak hours, transit, car‑pooling, or active modes, cutting vehicle miles, emissions, and average travel times; unlike building more roads (which induces demand) or banning cars (which is politically untenable), pricing is market‑based, scalable, and directly targets the root cause of congestion.', 'I would recommend a "Time-Driven Pricing" policy, which involves implementing variable tolls that depend on the time of day and traffic congestion. This policy would incentivize drivers to avoid peak hours and reduce the number of vehicles on the road, leading to reduced congestion and emissions. By tying tolls to time, this policy incentivizes behavioral changes that are more effective in reducing traffic than simply banning car use or building new roads.', '**Implement a dynamic congestion‑pricing system:** raise a toll on heavy‑traffic roads during peak hours. This pricing signals drivers to choose off‑peak times, alternate routes, or public transit, thus directly lowering peak traffic and emissions while generating revenue that can be reinvested in transit and bike infrastructure, shortening commutes overall. Unlike bans or new roads, it preserves the right to drive, activates immediately at a low cost, and has proven success in London, Singapore, and Hong Kong.', 'I recommend implementing a dynamic, real-time congestion and emission-based pricing system for all private vehicles. This policy adjusts the cost of driving—through variable fees and commuter credits—based on specific factors like time of day, current traffic density, and vehicle pollution levels. It is superior because it manages demand by making the *opportunity cost* of driving expensive during peak times, thus optimizing existing infrastructure without the political backlash of outright bans or the high expense of new construction.']

# %%
# It's nice to know how to use "zip"
for competitor, answer in zip(competitors, answers):
    print(f"Competitor: {competitor}\n\n{answer}")
# Out:
# Competitor: gpt-5.4-nano
#
# Adopt a citywide congestion pricing (tolling vehicles entering or driving through the most congested areas during peak hours). This directly targets traffic volumes by making trips at the times and places with the biggest delays more costly, which lowers congestion, emissions, and travel time without banning cars or building roads. Compared with obvious alternatives like fuel taxes or parking limits, it is more precisely tied to where/when congestion occurs, so it delivers faster, more predictable reductions in driving.
# Competitor: claude-sonnet-4-6
#
# I would recommend **congestion pricing** — charging drivers a variable fee to enter high-traffic zones during peak hours. It works better than alternatives like expanded public transit alone or parking restrictions because it directly attacks the root cause (the artificially low cost of driving in dense areas), generates revenue to fund transit improvements simultaneously, and creates a self-regulating system where prices rise precisely when and where congestion is worst. Evidence from London, Stockholm, and Singapore shows it measurably reduces traffic volume, cuts emissions, and shortens commute times without requiring new infrastructure or outright bans.
# Competitor: gemini-3.1-flash-lite
#
# I recommend implementing **dynamic congestion pricing**, which adjusts toll rates in real-time based on traffic volume to ensure roads remain at optimal capacity. Unlike infrastructure expansion, which induces further demand, or outright bans, which are politically and economically disruptive, this market-based approach incentivizes off-peak travel and public transit use. It effectively manages demand to reduce gridlock and emissions while generating immediate revenue to fund reliable, time-saving transportation alternatives.
# Competitor: openai/gpt-oss-120b
#
# Implement citywide congestion pricing with dynamic, time‑of‑day tolls on the most congested corridors. By internalizing the external costs of driving, it immediately shifts trips to off‑peak hours, transit, car‑pooling, or active modes, cutting vehicle miles, emissions, and average travel times; unlike building more roads (which induces demand) or banning cars (which is politically untenable), pricing is market‑based, scalable, and directly targets the root cause of congestion.
# Competitor: llama3.2:latest
#
# I would recommend a "Time-Driven Pricing" policy, which involves implementing variable tolls that depend on the time of day and traffic congestion. This policy would incentivize drivers to avoid peak hours and reduce the number of vehicles on the road, leading to reduced congestion and emissions. By tying tolls to time, this policy incentivizes behavioral changes that are more effective in reducing traffic than simply banning car use or building new roads.
# Competitor: gpt-oss:latest
#
# **Implement a dynamic congestion‑pricing system:** raise a toll on heavy‑traffic roads during peak hours. This pricing signals drivers to choose off‑peak times, alternate routes, or public transit, thus directly lowering peak traffic and emissions while generating revenue that can be reinvested in transit and bike infrastructure, shortening commutes overall. Unlike bans or new roads, it preserves the right to drive, activates immediately at a low cost, and has proven success in London, Singapore, and Hong Kong.
# Competitor: gemma4:latest
#
# I recommend implementing a dynamic, real-time congestion and emission-based pricing system for all private vehicles. This policy adjusts the cost of driving—through variable fees and commuter credits—based on specific factors like time of day, current traffic density, and vehicle pollution levels. It is superior because it manages demand by making the *opportunity cost* of driving expensive during peak times, thus optimizing existing infrastructure without the political backlash of outright bans or the high expense of new construction.

# %%
# Let's bring this together - note the use of "enumerate"

together = ""
for index, answer in enumerate(answers):
    together += f"# Response from competitor {index+1}\n\n"
    together += answer + "\n\n"

# %%
print(together)
# Out:
# # Response from competitor 1
#
# Adopt a citywide congestion pricing (tolling vehicles entering or driving through the most congested areas during peak hours). This directly targets traffic volumes by making trips at the times and places with the biggest delays more costly, which lowers congestion, emissions, and travel time without banning cars or building roads. Compared with obvious alternatives like fuel taxes or parking limits, it is more precisely tied to where/when congestion occurs, so it delivers faster, more predictable reductions in driving.
#
# # Response from competitor 2
#
# I would recommend **congestion pricing** — charging drivers a variable fee to enter high-traffic zones during peak hours. It works better than alternatives like expanded public transit alone or parking restrictions because it directly attacks the root cause (the artificially low cost of driving in dense areas), generates revenue to fund transit improvements simultaneously, and creates a self-regulating system where prices rise precisely when and where congestion is worst. Evidence from London, Stockholm, and Singapore shows it measurably reduces traffic volume, cuts emissions, and shortens commute times without requiring new infrastructure or outright bans.
#
# # Response from competitor 3
#
# I recommend implementing **dynamic congestion pricing**, which adjusts toll rates in real-time based on traffic volume to ensure roads remain at optimal capacity. Unlike infrastructure expansion, which induces further demand, or outright bans, which are politically and economically disruptive, this market-based approach incentivizes off-peak travel and public transit use. It effectively manages demand to reduce gridlock and emissions while generating immediate revenue to fund reliable, time-saving transportation alternatives.
#
# # Response from competitor 4
#
# Implement citywide congestion pricing with dynamic, time‑of‑day tolls on the most congested corridors. By internalizing the external costs of driving, it immediately shifts trips to off‑peak hours, transit, car‑pooling, or active modes, cutting vehicle miles, emissions, and average travel times; unlike building more roads (which induces demand) or banning cars (which is politically untenable), pricing is market‑based, scalable, and directly targets the root cause of congestion.
#
# # Response from competitor 5
#
# I would recommend a "Time-Driven Pricing" policy, which involves implementing variable tolls that depend on the time of day and traffic congestion. This policy would incentivize drivers to avoid peak hours and reduce the number of vehicles on the road, leading to reduced congestion and emissions. By tying tolls to time, this policy incentivizes behavioral changes that are more effective in reducing traffic than simply banning car use or building new roads.
#
# # Response from competitor 6
#
# **Implement a dynamic congestion‑pricing system:** raise a toll on heavy‑traffic roads during peak hours. This pricing signals drivers to choose off‑peak times, alternate routes, or public transit, thus directly lowering peak traffic and emissions while generating revenue that can be reinvested in transit and bike infrastructure, shortening commutes overall. Unlike bans or new roads, it preserves the right to drive, activates immediately at a low cost, and has proven success in London, Singapore, and Hong Kong.
#
# # Response from competitor 7
#
# I recommend implementing a dynamic, real-time congestion and emission-based pricing system for all private vehicles. This policy adjusts the cost of driving—through variable fees and commuter credits—based on specific factors like time of day, current traffic density, and vehicle pollution levels. It is superior because it manages demand by making the *opportunity cost* of driving expensive during peak times, thus optimizing existing infrastructure without the political backlash of outright bans or the high expense of new construction.

# %%
judge = f"""You are judging a competition between {len(competitors)} competitors.
Each model has been given this question:

{question}

Your job is to evaluate each response for clarity and strength of argument, and rank them in order of best to worst.
Respond with JSON, and only JSON, with the following format:
{{"results": ["best competitor number", "second best competitor number", "third best competitor number", ...]}}

Here are the responses from each competitor:

{together}

Now respond with the JSON with the ranked order of the competitors, nothing else. Do not include markdown formatting or code blocks."""

# %%
print(judge)
# Out:
# You are judging a competition between 7 competitors.
# Each model has been given this question:
#
# You are advising a city that wants to reduce traffic, air pollution, and commuting time without building new roads or banning cars. What single policy would you recommend, and why is it likely to work better than the obvious alternatives? Answer in no more than 3 sentences.
#
# Your job is to evaluate each response for clarity and strength of argument, and rank them in order of best to worst.
# Respond with JSON, and only JSON, with the following format:
# {"results": ["best competitor number", "second best competitor number", "third best competitor number", ...]}
#
# Here are the responses from each competitor:
#
# # Response from competitor 1
#
# Adopt a citywide congestion pricing (tolling vehicles entering or driving through the most congested areas during peak hours). This directly targets traffic volumes by making trips at the times and places with the biggest delays more costly, which lowers congestion, emissions, and travel time without banning cars or building roads. Compared with obvious alternatives like fuel taxes or parking limits, it is more precisely tied to where/when congestion occurs, so it delivers faster, more predictable reductions in driving.
#
# # Response from competitor 2
#
# I would recommend **congestion pricing** — charging drivers a variable fee to enter high-traffic zones during peak hours. It works better than alternatives like expanded public transit alone or parking restrictions because it directly attacks the root cause (the artificially low cost of driving in dense areas), generates revenue to fund transit improvements simultaneously, and creates a self-regulating system where prices rise precisely when and where congestion is worst. Evidence from London, Stockholm, and Singapore shows it measurably reduces traffic volume, cuts emissions, and shortens commute times without requiring new infrastructure or outright bans.
#
# # Response from competitor 3
#
# I recommend implementing **dynamic congestion pricing**, which adjusts toll rates in real-time based on traffic volume to ensure roads remain at optimal capacity. Unlike infrastructure expansion, which induces further demand, or outright bans, which are politically and economically disruptive, this market-based approach incentivizes off-peak travel and public transit use. It effectively manages demand to reduce gridlock and emissions while generating immediate revenue to fund reliable, time-saving transportation alternatives.
#
# # Response from competitor 4
#
# Implement citywide congestion pricing with dynamic, time‑of‑day tolls on the most congested corridors. By internalizing the external costs of driving, it immediately shifts trips to off‑peak hours, transit, car‑pooling, or active modes, cutting vehicle miles, emissions, and average travel times; unlike building more roads (which induces demand) or banning cars (which is politically untenable), pricing is market‑based, scalable, and directly targets the root cause of congestion.
#
# # Response from competitor 5
#
# I would recommend a "Time-Driven Pricing" policy, which involves implementing variable tolls that depend on the time of day and traffic congestion. This policy would incentivize drivers to avoid peak hours and reduce the number of vehicles on the road, leading to reduced congestion and emissions. By tying tolls to time, this policy incentivizes behavioral changes that are more effective in reducing traffic than simply banning car use or building new roads.
#
# # Response from competitor 6
#
# **Implement a dynamic congestion‑pricing system:** raise a toll on heavy‑traffic roads during peak hours. This pricing signals drivers to choose off‑peak times, alternate routes, or public transit, thus directly lowering peak traffic and emissions while generating revenue that can be reinvested in transit and bike infrastructure, shortening commutes overall. Unlike bans or new roads, it preserves the right to drive, activates immediately at a low cost, and has proven success in London, Singapore, and Hong Kong.
#
# # Response from competitor 7
#
# I recommend implementing a dynamic, real-time congestion and emission-based pricing system for all private vehicles. This policy adjusts the cost of driving—through variable fees and commuter credits—based on specific factors like time of day, current traffic density, and vehicle pollution levels. It is superior because it manages demand by making the *opportunity cost* of driving expensive during peak times, thus optimizing existing infrastructure without the political backlash of outright bans or the high expense of new construction.
#
#
#
# Now respond with the JSON with the ranked order of the competitors, nothing else. Do not include markdown formatting or code blocks.

# %%
judge_messages = [{"role": "user", "content": judge}]

# %% [markdown]
# ## And now for Grok!
#
# Branded as "The most truth-seeking large language model in the world".. so let's use it as our LLM as a judge

# %%
# Judgement time!
# Grok is "The most truth-seeking large language model in the world."

model_name = "gpt-5.4-nano-2026-03-17"

response = openai.chat.completions.create(model=model_name, messages=judge_messages)
results = response.choices[0].message.content
print(results)
# Out:
# {"results":["7","2","3","6","4","1","5"]}

# %%
# OK let's turn this into results!

results_dict = json.loads(results)
ranks = results_dict["results"]
for index, result in enumerate(ranks):
    competitor = competitors[int(result)-1]
    print(f"Rank {index+1}: {competitor}")
# Out:
# Rank 1: gemma4:latest
# Rank 2: claude-sonnet-4-6
# Rank 3: gemini-3.1-flash-lite
# Rank 4: gpt-oss:latest
# Rank 5: openai/gpt-oss-120b
# Rank 6: gpt-5.4-nano
# Rank 7: llama3.2:latest

# %% [markdown]
# <table style="margin: 0; text-align: left; width:100%">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../assets/exercise.png" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#ff7800;">Exercise</h2>
#             <span style="color:#ff7800;">Which pattern(s) did this use? Try updating this to add another Agentic design pattern.
#             </span>
#         </td>
#     </tr>
# </table>

# %% [markdown]
# <table style="margin: 0; text-align: left; width:100%">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../assets/business.png" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#00bfff;">Commercial implications</h2>
#             <span style="color:#00bfff;">These kinds of patterns - to send a task to multiple models, and evaluate results,
#             are common where you need to improve the quality of your LLM response. This approach can be universally applied
#             to business projects where accuracy is critical.
#             </span>
#         </td>
#     </tr>
# </table>
