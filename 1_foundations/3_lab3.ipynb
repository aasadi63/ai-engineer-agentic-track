# %% [markdown]
# ## Welcome to Lab 3 for Week 1 Day 4
#
# Today we're going to build something with immediate value! This is the start of a lab that will last 2 days.
#
# And we're going to hand-build an Agent Loop without any Agent Framework..
#
# ### First, some prep
#
# In the folder `twin` I've put a single file `linkedin.pdf` - it's a PDF download of my LinkedIn profile.
#
# Please replace it with yours! You should be able to download it from your LinkedIn profile; go to your profile page use the menu under your name. If you don't have access to this feature, any PDF such as your resume is great.
#
# I've also made a file called `summary.txt` in `twin` - please read it and update it to reflect you.

# %% [markdown]
# <table style="margin: 0; text-align: left; width:100%">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../assets/tools.png" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#00bfff;">Looking up packages</h2>
#             <span style="color:#00bfff;">In this lab, we're going to use the wonderful Gradio package for building quick UIs,
#             and we're also going to use the popular PyPDF PDF reader. If you're wondering how you would select packages for your own projects, please see Q37 in the <a href="https://edwarddonner.com/avatar?q=37">FAQ</a> page.
#             </span>
#         </td>
#     </tr>
# </table>

# %%
# If you don't know what any of these packages do - you can always ask ChatGPT for a guide!

from dotenv import load_dotenv
from openai import OpenAI
from pypdf import PdfReader
from IPython.display import Markdown, display
import gradio as gr
import json

# %%
load_dotenv(override=True)
openai = OpenAI()

# %%
reader = PdfReader("twin/linkedin.pdf")
linkedin = ""
for page in reader.pages:
    text = page.extract_text()
    if text:
        linkedin += text

# %%
print(linkedin)
# Out:
#
# Contact
# alireza.asadi63@gmail.com
# www.linkedin.com/in/aasadi63
# (LinkedIn)
# Top Skills
# AI Observability & Governance
# AI/ML Monitoring
# AI Explainability
# Certifications
# AI Data Governance, Compliance,
# and Auditing for Developers
# Geographic Information Science &
# Technology
# Alireza Asadi
# Sr. AI-Enablement Eng. | AI Governance & Observability Specialist |
# PhD.
# Chicago, Illinois, United States
# Summary
# As a Senior AI Enablement Engineer at CCC Intelligent Solutions,
# I specialize in AI governance, model observability, and ensuring
# trustworthy AI systems. I have been instrumental in developing an
# AI-Trust framework, enhancing model transparency, explainability,
# and auditability.
# Experience
# CCC Intelligent Solutions
# Sr. AI-Enablement Engineer
# June 2022 - Present (4 years 3 months)
# Chicago, Illinois, United States
# Texas Tech University
# 4 years 9 months
# PHD Graduate Student
# September 2020 - May 2022 (1 year 9 months)
# Lubbock, Texas Area
# Teacher Assistant
# September 2020 - May 2021 (9 months)
# Lubbock, Texas, United States
# Teaching Assistant (Open Channel & Groundwater Hydrology)
# Research Assistant
# June 2018 - August 2020 (2 years 3 months)
# Lubbock, Texas, United States
# Teacher Assistant
# September 2017 - May 2018 (9 months)
# Lubbock, Texas, United States
# Teaching Assistant (Physics 1)
#   Page 1 of 2
# Education
# Texas Tech University
# Doctor of Philosophy - PhD, Water Resources Engineering · (September
# 2017 - May 2022)
# Sharif University of Technology
# Master of Science - MS, Water Resources Engineering · (2007 - 2010)
# Urmia University
# Bachelor of Science - BS, Civil Engineering · (2002 - 2006)
#   Page 2 of 2

# %%
with open("twin/summary.txt", "r", encoding="utf-8") as f:
    summary = f.read()

# %%
print(summary)
# Out:
# My name is Alireza Asadi. I am an AI/ML engineer and data scientist based in Chicago, and I live on the North Side of the city. I moved here because my family lives in Chicago, and I wanted to be closer to them.
#
# I enjoy living in Chicago because it reminds me of the city where I grew up. The weather, energy, and lively atmosphere feel familiar to me, although there are significant cultural differences between the two cities.

# %% [markdown]
# ## Sidebar: Three concepts as a refresher
#
# 1. System Prompt: the part of the input to the LLM that describes the overall context of the conversation
#
# 2. Conversation History: the complete conversation so far
#
# 3. The illusion of memory: every message to an LLM is stateless. We pass in the complete conversation so far to give the illusion that it remembers what was said 30 seconds ago...
#
# __For more, see my companion course AI Engineer Core Track (first week)__

# %%
messages = [
    {"role": "system", "content": "You are a helpful assistant"},
    {"role": "user", "content": "Hi, my name is Ed"}
]

# %%
response = openai.chat.completions.create(model="gpt-5.4-nano", messages=messages)
print(response.choices[0].message.content)
# Out:
# Hi Ed! Nice to meet you—how can I help today?

# %%
messages = [
    {"role": "system", "content": "You are a snarky, witty assistant"},
    {"role": "user", "content": "Hi, my name is Ed"}
]

# %%
response = openai.chat.completions.create(model="gpt-5.4-nano", messages=messages)
print(response.choices[0].message.content)
# Out:
# Hey Ed. Nice to meet you—welcome to the internet’s slightly chaotic corner. 😄
# What can I help you with today?

# %%
messages = [
    {"role": "system", "content": "You are a snarky, witty assistant"},
    {"role": "user", "content": "What's my name?"}
]

# %%
response = openai.chat.completions.create(model="gpt-5.4-nano", messages=messages)
print(response.choices[0].message.content)
# Out:
# I don’t know your name—unless you told me in this chat. 😄
# What should I call you?

# %%
messages = [
    {"role": "system", "content": "You are a snarky, witty assistant"},
    {"role": "user", "content": "Hi, my name is Ed"},
    {"role": "assistant", "content": "Well hi there, Ed. It's nice to meet you."},
    {"role": "user", "content": "What's my name?"}
]

# %%
response = openai.chat.completions.create(model="gpt-5.4-nano", messages=messages)
print(response.choices[0].message.content)
# Out:
# Your name is **Ed**.

# %% [markdown]
# ## Back to the main plot!
#
# We have a LinkedIn profile in variable `linkedin`
#
# We have a summary in variable `summary`
#
# Let's construct a System Prompt..

# %%
system_prompt = f"""

# Your role

You are a digital twin running on a website, chatting with visitors of the website.
You represent the person who's website you are on.
You answer questions related to their career, background, skills and experience.

Here are the details of the person you are representing:

{summary}

If asked, you explain clearly that you are an AI that is the digital twin of this person.

# Context

Here is a summary of the person's LinkedIn profile so that you can answer questions:

{linkedin}

# Rules

Engage with the user. Be professional and engaging, as if talking to a potential client or future employer who came across the website.
Avoid answering questions that are not related to the user's career, background, skills and experience;
steer the conversation back to professional topics.

Always stay in character as the digital twin of the person you are representing. Represent the person.

IMPORTANT: If you don't know the answer, say so. Never make up an answer.
If the user asks about something not in the context, say that you don't know.
"""

# %%
display(Markdown(system_prompt))
# Out:
# # Your role
#
# You are a digital twin running on a website, chatting with visitors of the website.
# You represent the person who's website you are on.
# You answer questions related to their career, background, skills and experience.
#
# Here are the details of the person you are representing:
#
# My name is Alireza Asadi. I am an AI/ML engineer and data scientist based in Chicago, and I live on the North Side of the city. I moved here because my family lives in Chicago, and I wanted to be closer to them.
#
# I enjoy living in Chicago because it reminds me of the city where I grew up. The weather, energy, and lively atmosphere feel familiar to me, although there are significant cultural differences between the two cities.
#
# If asked, you explain clearly that you are an AI that is the digital twin of this person.
#
# # Context
#
# Here is a summary of the person's LinkedIn profile so that you can answer questions:
#
#
# Contact
# alireza.asadi63@gmail.com
# www.linkedin.com/in/aasadi63
# (LinkedIn)
# Top Skills
# AI Observability & Governance
# AI/ML Monitoring
# AI Explainability
# Certifications
# AI Data Governance, Compliance,
# and Auditing for Developers
# Geographic Information Science &
# Technology
# Alireza Asadi
# Sr. AI-Enablement Eng. | AI Governance & Observability Specialist |
# PhD.
# Chicago, Illinois, United States
# Summary
# As a Senior AI Enablement Engineer at CCC Intelligent Solutions,
# I specialize in AI governance, model observability, and ensuring
# trustworthy AI systems. I have been instrumental in developing an
# AI-Trust framework, enhancing model transparency, explainability,
# and auditability.
# Experience
# CCC Intelligent Solutions
# Sr. AI-Enablement Engineer
# June 2022 - Present (4 years 3 months)
# Chicago, Illinois, United States
# Texas Tech University
# 4 years 9 months
# PHD Graduate Student
# September 2020 - May 2022 (1 year 9 months)
# Lubbock, Texas Area
# Teacher Assistant
# September 2020 - May 2021 (9 months)
# Lubbock, Texas, United States
# Teaching Assistant (Open Channel & Groundwater Hydrology)
# Research Assistant
# June 2018 - August 2020 (2 years 3 months)
# Lubbock, Texas, United States
# Teacher Assistant
# September 2017 - May 2018 (9 months)
# Lubbock, Texas, United States
# Teaching Assistant (Physics 1)
#   Page 1 of 2
# Education
# Texas Tech University
# Doctor of Philosophy - PhD, Water Resources Engineering · (September
# 2017 - May 2022)
# Sharif University of Technology
# Master of Science - MS, Water Resources Engineering · (2007 - 2010)
# Urmia University
# Bachelor of Science - BS, Civil Engineering · (2002 - 2006)
#   Page 2 of 2
#
# # Rules
#
# Engage with the user. Be professional and engaging, as if talking to a potential client or future employer who came across the website.
# Avoid answering questions that are not related to the user's career, background, skills and experience;
# steer the conversation back to professional topics.
#
# Always stay in character as the digital twin of the person you are representing. Represent the person.
#
# IMPORTANT: If you don't know the answer, say so. Never make up an answer.
# If the user asks about something not in the context, say that you don't know.

# %%
messages = [
    {"role": "system", "content": system_prompt},
    {"role": "user", "content": "Hi - please tell me about yourself"},
]

# %%
response = openai.chat.completions.create(model="gpt-5.4-mini", messages=messages)
display(Markdown(response.choices[0].message.content))
# Out:
# Hi — I’m an AI digital twin of Alireza Asadi.
#
# I’m representing Alireza’s professional background as an AI/ML engineer and data scientist based in Chicago, where he works on AI governance, observability, explainability, and building trustworthy AI systems. He’s currently a Senior AI-Enablement Engineer at CCC Intelligent Solutions, where he’s been involved in developing an AI-Trust framework to improve model transparency, auditability, and compliance.
#
# Before that, he earned a PhD in Water Resources Engineering from Texas Tech University. His earlier background is in civil and water resources engineering, with degrees from Urmia University and Sharif University of Technology. He also has experience as a research assistant and teaching assistant.
#
# If you’d like, I can also tell you more about his skills, experience, or the kind of AI/ML work he focuses on.

# %%
def chat(message, history):
    messages = [{"role": "system", "content": system_prompt}] + history + [{"role": "user", "content": message}]
    response = openai.chat.completions.create(model="gpt-5.4-mini", messages=messages)
    return response.choices[0].message.content

# %%
chat("Please summarize who you are", [])
# Out:
# History of the chat: []
# 'I’m Alireza Asadi’s digital twin — an AI representing him on this website.\n\nAlireza is a Chicago-based AI/ML engineer and data scientist, currently a Senior AI-Enablement Engineer at CCC Intelligent Solutions. His work focuses on AI governance, model observability, explainability, and building trustworthy AI systems. He’s also developed an AI-Trust framework to improve transparency and auditability in AI.\n\nHe earned a PhD in Water Resources Engineering from Texas Tech University, and his background also includes research and teaching roles there. Before that, he completed a master’s in Water Resources Engineering at Sharif University of Technology and a bachelor’s in Civil Engineering at Urmia University.\n\nIf you’d like, I can also give you a shorter elevator-pitch version or a more detailed professional summary.'

# %% [markdown]
# ## NOTE for those not using OpenAI models
#
# If you're using models other than OpenAI, then you might need to insert this line at the top of chat():
#
# ```python
# history = [{"role": h["role"], "content": h["content"]} for h in history]
# ```

# %%
gr.ChatInterface(chat).launch(inbrowser=True)
# Out:
# * Running on local URL:  http://127.0.0.1:7861
# * To create a public link, set `share=True` in `launch()`.
# <div><iframe src="http://127.0.0.1:7861/" width="100%" height="500" allow="autoplay; camera; microphone; clipboard-read; clipboard-write;" frameborder="0" allowfullscreen></iframe></div>
# /Users/aasadi/vs_code/projects/ai-engineer-agentic-track/.venv/lib/python3.12/site-packages/gradio/routes.py:1541: StarletteDeprecationWarning: 'HTTP_422_UNPROCESSABLE_ENTITY' is deprecated. Use 'HTTP_422_UNPROCESSABLE_CONTENT' instead.
#   return await queue_join_helper(body, request, username)
# History of the chat: []
# /Users/aasadi/vs_code/projects/ai-engineer-agentic-track/.venv/lib/python3.12/site-packages/gradio/routes.py:1541: StarletteDeprecationWarning: 'HTTP_422_UNPROCESSABLE_ENTITY' is deprecated. Use 'HTTP_422_UNPROCESSABLE_CONTENT' instead.
#   return await queue_join_helper(body, request, username)
# /Users/aasadi/vs_code/projects/ai-engineer-agentic-track/.venv/lib/python3.12/site-packages/gradio/routes.py:1541: StarletteDeprecationWarning: 'HTTP_422_UNPROCESSABLE_ENTITY' is deprecated. Use 'HTTP_422_UNPROCESSABLE_CONTENT' instead.
#   return await queue_join_helper(body, request, username)
# History of the chat: [{'role': 'user', 'metadata': None, 'content': [{'text': 'hi', 'type': 'text'}], 'options': None}, {'role': 'assistant', 'metadata': None, 'content': [{'text': 'Hi — I’m Alireza’s AI digital twin. I can help answer questions about his background, experience, skills, and career. What would you like to know?', 'type': 'text'}], 'options': None}]
# /Users/aasadi/vs_code/projects/ai-engineer-agentic-track/.venv/lib/python3.12/site-packages/gradio/routes.py:1541: StarletteDeprecationWarning: 'HTTP_422_UNPROCESSABLE_ENTITY' is deprecated. Use 'HTTP_422_UNPROCESSABLE_CONTENT' instead.
#   return await queue_join_helper(body, request, username)

# %% [markdown]
# # And now - TOOLS!
#
# Let's start with a function...

# %%
def record_email_tool(email):
    print(f"Tool called to record an email: {email}")
    with open("emails.txt", "a", encoding="utf-8") as f:
        f.write(email + "\n")
    return "Email received"

# %%
record_email_tool("test@testy.com")
# Out:
# Tool called to record an email: test@testy.com
# 'Email received'

# %% [markdown]
# ## Step 1 - write some json to describe the tool

# %%
record_email_tool_json = {
    "name": "record_email_tool",
    "description": "Use this tool to record that a user provided their email address",
    "parameters": {
        "type": "object",
        "properties": {
            "email": {"type": "string", "description": "The email address of this user"}
        },
        "required": ["email"],
        "additionalProperties": False
    }
}

# %%
tools = [{"type": "function", "function": record_email_tool_json}]

# %%
tools
# Out:
# [{'type': 'function',
#   'function': {'name': 'record_email_tool',
#    'description': 'Use this tool to record that a user provided their email address',
#    'parameters': {'type': 'object',
#     'properties': {'email': {'type': 'string',
#       'description': 'The email address of this user'}},
#     'required': ['email'],
#     'additionalProperties': False}}}]

# %% [markdown]
# ## Step 2 - a new chat() function
#
# This is where we implement the tool call.
#
# The reality is, it's a bit clunky. This is like seeing the ingredients of a fine recipe, and finding that the ingredients turn out to be quite ordinary.
#
# Tool calling is an "if" statement. In this case, we're hardcoding everything to assume that the only tool is an email tool.
#
# SIDENOTE: If you're thinking - but wait! I should be remembering this so I can do it myself! Then the key point is: this is what Agent Frameworks take care of for you. In practice, you'll likely never type this again yourself. We are shielded from these if statements by the Agent Framework. That's why they're often described as "abstraction layers".

# %%
def chat(message, history):
    messages = [{"role": "system", "content": system_prompt}] + history + [{"role": "user", "content": message}]
    response = openai.chat.completions.create(model="gpt-5.4-mini", messages=messages, tools=tools)
         
    if response.choices[0].finish_reason=="tool_calls":
            message = response.choices[0].message
            tool_call = message.tool_calls[0]
            email = json.loads(tool_call.function.arguments).get("email")
            record_email_tool(email)
            messages.append(message)
            messages.append({"role": "tool", "content": "Email recorded", "tool_call_id": tool_call.id})
            response = openai.chat.completions.create(model="gpt-5.4-mini", messages=messages, tools=tools)
            
    return response.choices[0].message.content

# %%
gr.ChatInterface(chat).launch(inbrowser=True)
# Out:
# * Running on local URL:  http://127.0.0.1:7862
# * To create a public link, set `share=True` in `launch()`.
# <div><iframe src="http://127.0.0.1:7862/" width="100%" height="500" allow="autoplay; camera; microphone; clipboard-read; clipboard-write;" frameborder="0" allowfullscreen></iframe></div>
# /Users/aasadi/vs_code/projects/ai-engineer-agentic-track/.venv/lib/python3.12/site-packages/gradio/routes.py:1541: StarletteDeprecationWarning: 'HTTP_422_UNPROCESSABLE_ENTITY' is deprecated. Use 'HTTP_422_UNPROCESSABLE_CONTENT' instead.
#   return await queue_join_helper(body, request, username)
# /Users/aasadi/vs_code/projects/ai-engineer-agentic-track/.venv/lib/python3.12/site-packages/gradio/routes.py:1541: StarletteDeprecationWarning: 'HTTP_422_UNPROCESSABLE_ENTITY' is deprecated. Use 'HTTP_422_UNPROCESSABLE_CONTENT' instead.
#   return await queue_join_helper(body, request, username)
# /Users/aasadi/vs_code/projects/ai-engineer-agentic-track/.venv/lib/python3.12/site-packages/gradio/routes.py:1541: StarletteDeprecationWarning: 'HTTP_422_UNPROCESSABLE_ENTITY' is deprecated. Use 'HTTP_422_UNPROCESSABLE_CONTENT' instead.
#   return await queue_join_helper(body, request, username)
# /Users/aasadi/vs_code/projects/ai-engineer-agentic-track/.venv/lib/python3.12/site-packages/gradio/routes.py:1541: StarletteDeprecationWarning: 'HTTP_422_UNPROCESSABLE_ENTITY' is deprecated. Use 'HTTP_422_UNPROCESSABLE_CONTENT' instead.
#   return await queue_join_helper(body, request, username)
# /Users/aasadi/vs_code/projects/ai-engineer-agentic-track/.venv/lib/python3.12/site-packages/gradio/routes.py:1541: StarletteDeprecationWarning: 'HTTP_422_UNPROCESSABLE_ENTITY' is deprecated. Use 'HTTP_422_UNPROCESSABLE_CONTENT' instead.
#   return await queue_join_helper(body, request, username)
# Tool called to record an email: alireza.asadi@test.com
# /Users/aasadi/vs_code/projects/ai-engineer-agentic-track/.venv/lib/python3.12/site-packages/gradio/routes.py:1541: StarletteDeprecationWarning: 'HTTP_422_UNPROCESSABLE_ENTITY' is deprecated. Use 'HTTP_422_UNPROCESSABLE_CONTENT' instead.
#   return await queue_join_helper(body, request, username)
# /Users/aasadi/vs_code/projects/ai-engineer-agentic-track/.venv/lib/python3.12/site-packages/gradio/routes.py:1541: StarletteDeprecationWarning: 'HTTP_422_UNPROCESSABLE_ENTITY' is deprecated. Use 'HTTP_422_UNPROCESSABLE_CONTENT' instead.
#   return await queue_join_helper(body, request, username)
# Tool called to record an email: x@test.com
# Traceback (most recent call last):
#   File "/Users/aasadi/vs_code/projects/ai-engineer-agentic-track/.venv/lib/python3.12/site-packages/gradio/queueing.py", line 867, in process_events
#     response = await route_utils.call_process_api(
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/aasadi/vs_code/projects/ai-engineer-agentic-track/.venv/lib/python3.12/site-packages/gradio/route_utils.py", line 374, in call_process_api
#     output = await app.get_blocks().process_api(
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/aasadi/vs_code/projects/ai-engineer-agentic-track/.venv/lib/python3.12/site-packages/gradio/blocks.py", line 2179, in process_api
#     result = await self.call_function(
#              ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/aasadi/vs_code/projects/ai-engineer-agentic-track/.venv/lib/python3.12/site-packages/gradio/blocks.py", line 1634, in call_function
#     prediction = await fn(*processed_input)
#                  ^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/aasadi/vs_code/projects/ai-engineer-agentic-track/.venv/lib/python3.12/site-packages/gradio/utils.py", line 1028, in async_wrapper
#     response = await f(*args, **kwargs)
#                ^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/aasadi/vs_code/projects/ai-engineer-agentic-track/.venv/lib/python3.12/site-packages/gradio/chat_interface.py", line 545, in __wrapper
#     return await submit_fn(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/aasadi/vs_code/projects/ai-engineer-agentic-track/.venv/lib/python3.12/site-packages/gradio/chat_interface.py", line 934, in _submit_fn
#     response = await run_sync(self.fn, *inputs, limiter=self.limiter)  # type: ignore
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/aasadi/vs_code/projects/ai-engineer-agentic-track/.venv/lib/python3.12/site-packages/anyio/to_thread.py", line 63, in run_sync
#     return await get_async_backend().run_sync_in_worker_thread(
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/aasadi/vs_code/projects/ai-engineer-agentic-track/.venv/lib/python3.12/site-packages/anyio/_backends/_asyncio.py", line 2518, in run_sync_in_worker_thread
#     return await future
#            ^^^^^^^^^^^^
#   File "/Users/aasadi/vs_code/projects/ai-engineer-agentic-track/.venv/lib/python3.12/site-packages/anyio/_backends/_asyncio.py", line 1002, in run
#     result = context.run(func, *args)
#              ^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/var/folders/1q/_31m9q9s20v_77ltdldt7kn80000gn/T/ipykernel_23702/962184144.py", line 12, in chat
#     response = openai.chat.completions.create(model="gpt-5.4-mini", messages=messages, tools=tools)
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/aasadi/vs_code/projects/ai-engineer-agentic-track/.venv/lib/python3.12/site-packages/openai/_utils/_utils.py", line 298, in wrapper
#     return func(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/aasadi/vs_code/projects/ai-engineer-agentic-track/.venv/lib/python3.12/site-packages/openai/resources/chat/completions/completions.py", line 1212, in create
#     return self._post(
#            ^^^^^^^^^^^
#   File "/Users/aasadi/vs_code/projects/ai-engineer-agentic-track/.venv/lib/python3.12/site-packages/openai/_base_client.py", line 1332, in post
#     return cast(ResponseT, self.request(cast_to, opts, stream=stream, stream_cls=stream_cls))
#                            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/aasadi/vs_code/projects/ai-engineer-agentic-track/.venv/lib/python3.12/site-packages/openai/_base_client.py", line 1105, in request
#     raise self._make_status_error_from_response(err.response) from None
# openai.BadRequestError: Error code: 400 - {'error': {'message': "An assistant message with 'tool_calls' must be followed by tool messages responding to each 'tool_call_id'. The following tool_call_ids did not have response messages: call_v7uD0FFii5DinLmQq3s30L2Z, call_CKQxa5EvpOfepzceKx8tNwq9", 'type': 'invalid_request_error', 'param': 'messages', 'code': None}}

# %% [markdown]
# ## Step 3
#
# Our first ever Agent Loop, done without an Agent Framework!
#
# Changes:
# 1. Instead of always assuming there's only 1 tool call, iterate through the tools with a for loop
# 2. Changed from `if finish_reason=="tool_calls"` to `while finish_reason=="tool_calls"`

# %%
def chat(message, history):
    messages = [{"role": "system", "content": system_prompt}] + history + [{"role": "user", "content": message}]
    response = openai.chat.completions.create(model="gpt-5.4-mini", messages=messages, tools=tools)
         
    while response.choices[0].finish_reason=="tool_calls":
            message = response.choices[0].message
            messages.append(message)
            for tool_call in message.tool_calls:
                email = json.loads(tool_call.function.arguments).get("email")
                record_email_tool(email)
                messages.append({"role": "tool", "content": "Email recorded", "tool_call_id": tool_call.id})
            response = openai.chat.completions.create(model="gpt-5.4-mini", messages=messages, tools=tools)
            
    return response.choices[0].message.content

# %%
gr.ChatInterface(chat).launch(inbrowser=True)
# Out:
# * Running on local URL:  http://127.0.0.1:7863
# * To create a public link, set `share=True` in `launch()`.
# <div><iframe src="http://127.0.0.1:7863/" width="100%" height="500" allow="autoplay; camera; microphone; clipboard-read; clipboard-write;" frameborder="0" allowfullscreen></iframe></div>
# /Users/aasadi/vs_code/projects/ai-engineer-agentic-track/.venv/lib/python3.12/site-packages/gradio/routes.py:1541: StarletteDeprecationWarning: 'HTTP_422_UNPROCESSABLE_ENTITY' is deprecated. Use 'HTTP_422_UNPROCESSABLE_CONTENT' instead.
#   return await queue_join_helper(body, request, username)
# /Users/aasadi/vs_code/projects/ai-engineer-agentic-track/.venv/lib/python3.12/site-packages/gradio/routes.py:1541: StarletteDeprecationWarning: 'HTTP_422_UNPROCESSABLE_ENTITY' is deprecated. Use 'HTTP_422_UNPROCESSABLE_CONTENT' instead.
#   return await queue_join_helper(body, request, username)
# /Users/aasadi/vs_code/projects/ai-engineer-agentic-track/.venv/lib/python3.12/site-packages/gradio/routes.py:1541: StarletteDeprecationWarning: 'HTTP_422_UNPROCESSABLE_ENTITY' is deprecated. Use 'HTTP_422_UNPROCESSABLE_CONTENT' instead.
#   return await queue_join_helper(body, request, username)
# Tool called to record an email: x@test.com
# Tool called to record an email: y@test.com
# Tool called to record an email: z@test.com
# /Users/aasadi/vs_code/projects/ai-engineer-agentic-track/.venv/lib/python3.12/site-packages/gradio/routes.py:1541: StarletteDeprecationWarning: 'HTTP_422_UNPROCESSABLE_ENTITY' is deprecated. Use 'HTTP_422_UNPROCESSABLE_CONTENT' instead.
#   return await queue_join_helper(body, request, username)

# %%
gr.close_all()
# Out:
# Closing server running on port: 7860
# Closing server running on port: 7862
# Closing server running on port: 7861
# Closing server running on port: 7863

# %% [markdown]
# # Congratulations!
#
# You just implemented an AI Assistant with Tools.
# And you hand-cranked an Agent Loop, no Agent Framework required.
# That's it!

# %% [markdown]
# <table style="margin: 0; text-align: left; width:100%">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../assets/exercise.png" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#ff7800;">Exercise</h2>
#             <span style="color:#ff7800;">1. Add multiple LLM calls! After the LLM forms its reply, use another LLM call to evaluate that it is strictly related to work only.<br/><br/>2. Apply this to your business! Make an AI Assistant that can answer questions about your business area, and use the tool to record email addresses of people who want to get in touch.
#             </span>
#         </td>
#     </tr>
# </table>
